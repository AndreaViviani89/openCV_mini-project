# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('il-signore-degli-anelli.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_copy = rgb_img.copy()

# %%
plt.figure(figsize=(18,14))
cv2.putText(img_copy, 'ONE DOES NOT SIMPLY', (75, 150), cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 0, 0), 12)
cv2.putText(img_copy, 'ONE DOES NOT SIMPLY', (75, 150), cv2.FONT_HERSHEY_SIMPLEX, 3, (255, 255, 255), 8)
cv2.putText(img_copy, 'DRINK CAPPUCCINO AFTER 11', (75, 620), cv2.FONT_HERSHEY_SIMPLEX, 2.5, (0, 0, 0), 12)
cv2.putText(img_copy, 'DRINK CAPPUCCINO AFTER 11', (75, 620), cv2.FONT_HERSHEY_SIMPLEX, 2.5, (255, 255, 255), 8)
plt.imshow(img_copy)
plt.savefig('meme.png')
